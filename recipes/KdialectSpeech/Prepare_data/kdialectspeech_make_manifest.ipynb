# %%
import pandas as pd
import numpy as np

# %%
manifest_file = "/data/MTDATA/fn-2-018/sentence/total.csv"

# %%
total_manifest_df = pd.read_csv(manifest_file)

# %%
# split total csv into train, valid, test
total_manifest_train_df, total_manifest_valid_df, total_manifest_test_df = np.split(
    total_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(total_manifest_df)), int(.9*len(total_manifest_df))]
)

# %%
total_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/total_train.csv"
total_manifest_train_df.to_csv(total_manifest_train_file, index=False)
# train_total_manifest_df

# %%
total_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/total_valid.csv"
total_manifest_valid_df.to_csv(total_manifest_valid_file, index=False)

# %%
total_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/total_test.csv"
total_manifest_test_df.to_csv(total_manifest_test_file, index=False)

# %%
total_short_100 = total_manifest_df.sort_values(by=['duration']).head(100)
# total_short_100

total_short_100_file = "/data/MTDATA/fn-2-018/sentence/total_short_100.csv"
total_short_100.to_csv(total_short_100_file, index=False)
total_short_100
# Out:
#                                                        ID  duration  \
# 322022  say_set1_collectorgs303_speakergs3004_55_0_112-18     0.073
# 145993  talk_set1_collectorcc109_speakercc1209_speaker...     0.077
# 164355  talk_set3_collectorjl141_speakerjl2454_speaker...     0.086
# 242715  talk_set1_collectorgw78_speakergw2246_speakerg...     0.090
# 242160  talk_set3_collectorgw78_speakergw2040_speakerg...     0.094
# ...                                                   ...       ...
# 198465  talk_set1_collectorjl115_speakerjl2266_speaker...     0.100
# 27783   talk_set3_collectorgs414_speakergs4542_speaker...     0.100
# 122195  talk_set2_collectorcc132_speakercc764_speakerc...     0.100
# 27903   talk_set3_collectorgs414_speakergs3562_speaker...     0.100
# 544706      say_set2_collectorcc76_speakercc2472_0_0_28-0     0.100
#
#                                                       wav province_code    wrd
# 322022  /data/MTDATA/fn-2-018/sentence/person/say/gs/c...         total  죄송합니다
# 145993  /data/MTDATA/fn-2-018/sentence/people/talk/cc/...         total    그니까
# 164355  /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total    그니까
# 242715  /data/MTDATA/fn-2-018/sentence/people/talk/gw/...         total     외국
# 242160  /data/MTDATA/fn-2-018/sentence/people/talk/gw/...         total    맞아요
# ...                                                   ...           ...    ...
# 198465  /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total     맞아
# 27783   /data/MTDATA/fn-2-018/sentence/people/talk/gs/...         total   했는거네
# 122195  /data/MTDATA/fn-2-018/sentence/people/talk/cc/...         total      아
# 27903   /data/MTDATA/fn-2-018/sentence/people/talk/gs/...         total      예
# 544706  /data/MTDATA/fn-2-018/sentence/person/say/cc/c...         total   밥상이요
#
# [100 rows x 5 columns]

# %%
total_long_100 = total_manifest_df.sort_values(by=['duration'], ascending=False).head(100)
# total_short_100

total_long_100_file = "/data/MTDATA/fn-2-018/sentence/total_long_100.csv"
total_long_100.to_csv(total_long_100_file, index=False)
total_long_100
# Out:
#                                                         ID  duration  \
# 90053    talk_set3_collectorcc113_speakercc1760_speaker...   318.351
# 79173    talk_set3_collectorcc113_speakercc1760_speaker...   190.459
# 816795    say_set1_collectorjl129_speakerjl1833_16_0_168-0   166.900
# 1020534     say_set2_collectorjj83_speakerjj634_31_0_167-0   165.018
# 909764    say_set1_collectorgw137_speakergw2427_54_0_161-0   160.030
# ...                                                    ...       ...
# 690381      say_set1_collectorjl106_speakerjl435_18_0_93-0    92.310
# 68209    talk_set2_collectorgs119_speakergs1680_speaker...    92.300
# 1596     talk_set1_collectorgs198_speakergs1258_speaker...    91.670
# 454539     say_set1_collectorgs197_speakergs1203_35_0_93-0    91.579
# 72080    talk_set1_collectorgs382_speakergs2758_speaker...    91.149
#
#                                                        wav province_code  \
# 90053    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...         total
# 79173    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...         total
# 816795   /data/MTDATA/fn-2-018/sentence/person/say/jl/c...         total
# 1020534  /data/MTDATA/fn-2-018/sentence/person/say/jj/c...         total
# 909764   /data/MTDATA/fn-2-018/sentence/person/say/gw/c...         total
# ...                                                    ...           ...
# 690381   /data/MTDATA/fn-2-018/sentence/person/say/jl/c...         total
# 68209    /data/MTDATA/fn-2-018/sentence/people/talk/gs/...         total
# 1596     /data/MTDATA/fn-2-018/sentence/people/talk/gs/...         total
# 454539   /data/MTDATA/fn-2-018/sentence/person/say/gs/c...         total
# 72080    /data/MTDATA/fn-2-018/sentence/people/talk/gs/...         total
#
#                                                        wrd
# 90053    그랬다가 이제 사표 내고 가정으로 들어갔는데 그 신우랑 이제 같이 갔어 서울 본사로...
# 79173    나 좀 살려달라고 그랬더니 왜 그러시냐 우리 아저씨가 불이 사고로 이렇게 갑자기 이...
# 816795   명절에 내 가족이라 하면 지금은 단순 가족이라 해가지고 지금은 애기들 와도 서울에서...
# 1020534  우리 집에는 아버지가 살아계실 때 있을 땐 제사가 열여섯 번 일어나 죽게 우리 큰나...
# 909764   우리 애들은요 아들만 둘이 있는데요 큰 아들은요 아주 잘도 생겼고요 아가 차분해요 ...
# ...                                                    ...
# 690381   이제 그 친구라는 것은 이렇게 진짜 이상한 게 멀리 다 떨어져서 살더라고 그래서 학...
# 68209    얼마 전에는 또 우리 여기 전원주택이라고 시골 생활 이걸 선호했는데 내 친구들도 가...
# 1596     손자 손녀를 저거 뭐고 엄마 아버지가 뭐 맞벌이 부부를 하든가 이레 해가지고는 애들...
# 454539   제가 학교 다닐 때 방학 때 언니 집에 놀러 갔는데 우리 언니가 음 진해에 있었어요...
# 72080    하는데 조카들 키운다고 손목 나가고 발목 나가고 허리 나가고 진짜 아팠다 근데 지금...
#
# [100 rows x 5 columns]

# %%
gw_filter = total_manifest_df["ID"].str.contains("speakergw")
gw_manifest_df = total_manifest_df[gw_filter]
gw_manifest_df['province_code'] = gw_manifest_df['province_code'].replace('total','gw')
gw_manifest_df
# Out:
# /tmp/ipykernel_365916/3596631995.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gw_manifest_df['province_code'] = gw_manifest_df['province_code'].replace('total','gw')
#                                                         ID  duration  \
# 230943   talk_set1_collectorgw99_speakergw459_speakergw...     4.151
# 230944   talk_set1_collectorgw99_speakergw459_speakergw...     1.948
# 230945   talk_set1_collectorgw99_speakergw459_speakergw...     0.817
# 230946   talk_set1_collectorgw99_speakergw459_speakergw...     4.779
# 230947   talk_set1_collectorgw99_speakergw459_speakergw...     0.386
# ...                                                    ...       ...
# 1321921         st_set1_collectorgw133_speakergw829_70_6-0     5.770
# 1321922        st_set1_collectorgw133_speakergw739_21_10-0     9.439
# 1321923        st_set1_collectorgw133_speakergw739_100_9-0     8.070
# 1321924         st_set1_collectorgw133_speakergw739_50_8-0     8.066
# 1321925         st_set1_collectorgw133_speakergw739_57_8-0     8.019
#
#                                                        wav province_code  \
# 230943   /data/MTDATA/fn-2-018/sentence/people/talk/gw/...            gw
# 230944   /data/MTDATA/fn-2-018/sentence/people/talk/gw/...            gw
# 230945   /data/MTDATA/fn-2-018/sentence/people/talk/gw/...            gw
# 230946   /data/MTDATA/fn-2-018/sentence/people/talk/gw/...            gw
# 230947   /data/MTDATA/fn-2-018/sentence/people/talk/gw/...            gw
# ...                                                    ...           ...
# 1321921  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gw
# 1321922  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gw
# 1321923  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gw
# 1321924  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gw
# 1321925  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gw
#
#                                                        wrd
# 230943                      어머 자기는 뭐 좋아해 나는 회가 난 굉장히 좋아하거든
# 230944                                  회를 좋아해요 어머 나 회 싫어해
# 230945                                         어머 어머 어머 그래
# 230946                  왜냐하면은 그 날 것에 대해서 별로 안 좋은 기억이 있어가지고
# 230947                                                   어
# ...                                                    ...
# 1321921     이거이 운동화가 좀 큰지 헐거워 보이는데 끈을 단데히 짜매야지 안 그러면 넘어진대요
# 1321922  내가 지금은 이래 뚱땅해도 젊었을 적에는 개무잔데이 같다는 소리 들었는데 이게이 다...
# 1321923  아국쟁이에 계속 불을 떼는데 연기가 잘 안 빠지는 것을 보이까 까져먹지 말고 굴대통...
# 1321924  은어를 서울 사람들이 오믄 그러 찾는데 내 생각에 은어를 맴 맴내가 나서 회로는 벨루래요
# 1321925  우리 집 가아지가 갑자기 눈둥거리가 퉁퉁 벗고 가랩은 같은데 이거이 또 내가 볼 때...
#
# [229784 rows x 5 columns]

# %%
gw_manifest_file = "/data/MTDATA/fn-2-018/sentence/gw.csv"
gw_manifest_df = pd.read_csv(gw_manifest_file)

# split total csv into train, valid, test
gw_manifest_train_df, gw_manifest_valid_df, gw_manifest_test_df = np.split(
    gw_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(gw_manifest_df)), int(.9*len(gw_manifest_df))]
)

gw_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/gw_train.csv"
gw_manifest_train_df.to_csv(gw_manifest_train_file, index=False)

gw_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/gw_valid.csv"
gw_manifest_valid_df.to_csv(gw_manifest_valid_file, index=False)

gw_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/gw_test.csv"
gw_manifest_test_df.to_csv(gw_manifest_test_file, index=False)

# %%
gs_filter = total_manifest_df["ID"].str.contains("speakergs")
gs_manifest_df = total_manifest_df[gs_filter]
gs_manifest_df['province_code'] = gs_manifest_df['province_code'].replace('total','gs')
gs_manifest_df
# Out:
# /tmp/ipykernel_365916/1527978697.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gs_manifest_df['province_code'] = gs_manifest_df['province_code'].replace('total','gs')
#                                                         ID  duration  \
# 0        talk_set1_collectorgs217_speakergs2272_speaker...     1.059
# 1        talk_set1_collectorgs217_speakergs2272_speaker...     9.940
# 2        talk_set1_collectorgs217_speakergs2272_speaker...     1.970
# 3        talk_set1_collectorgs217_speakergs2272_speaker...     4.430
# 4        talk_set1_collectorgs217_speakergs2272_speaker...     7.330
# ...                                                    ...       ...
# 1314440         st_set1_collectorgw35_speakergs826_64_16-0     3.119
# 1314441         st_set1_collectorgw35_speakergs826_64_16-1     6.070
# 1314442         st_set1_collectorgw35_speakergs826_31_12-0     2.210
# 1314443         st_set1_collectorgw35_speakergs826_31_12-1     4.010
# 1314444         st_set1_collectorgw35_speakergs826_31_12-2     1.830
#
#                                                        wav province_code  \
# 0        /data/MTDATA/fn-2-018/sentence/people/talk/gs/...            gs
# 1        /data/MTDATA/fn-2-018/sentence/people/talk/gs/...            gs
# 2        /data/MTDATA/fn-2-018/sentence/people/talk/gs/...            gs
# 3        /data/MTDATA/fn-2-018/sentence/people/talk/gs/...            gs
# 4        /data/MTDATA/fn-2-018/sentence/people/talk/gs/...            gs
# ...                                                    ...           ...
# 1314440  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gs
# 1314441  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gs
# 1314442  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gs
# 1314443  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gs
# 1314444  /data/MTDATA/fn-2-018/sentence/person/st/gw/co...            gs
#
#                                                        wrd
# 0                                                 용돈이 더 좋다
# 1        선물은 잘못 사가 오니까 마음에 안 들더라고 또 마음에 안 들고 용돈을 주면 내 마...
# 2                                               그렇죠 용돈이 좋죠
# 3                       그래야 내가 사고 싶은 거를 사는 게 나으니까 용돈이 더 좋죠
# 4          선물 뭐 받을 때 기분은 좋은데 있는 게 또 있을 수도 있고 그러니까 용돈이 더 좋다
# ...                                                    ...
# 1314440                                  길 가다가 차에 쪼매 부딪혔는디
# 1314441                          그캐도 병원에서 진찰을 받아 보긴 기 좋겄지요
# 1314442                                          낚수 하려고 하이
# 1314443                                   껄겡이가 필요한디 어데를 파만
# 1314444                                           껄겡이가 많은겨
#
# [324367 rows x 5 columns]

# %%
gs_manifest_file = "/data/MTDATA/fn-2-018/sentence/gs.csv"
gs_manifest_df = pd.read_csv(gs_manifest_file)

# split total csv into train, valid, test
gs_manifest_train_df, gs_manifest_valid_df, gs_manifest_test_df = np.split(
    gs_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(gs_manifest_df)), int(.9*len(gs_manifest_df))]
)

gs_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/gs_train.csv"
gs_manifest_train_df.to_csv(gs_manifest_train_file, index=False)

gs_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/gs_valid.csv"
gs_manifest_valid_df.to_csv(gs_manifest_valid_file, index=False)

gs_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/gs_test.csv"
gs_manifest_test_df.to_csv(gs_manifest_test_file, index=False)

# %%
jl_filter = total_manifest_df["ID"].str.contains("speakerjl")
jl_manifest_df = total_manifest_df[jl_filter]
jl_manifest_df['province_code'] = jl_manifest_df['province_code'].replace('total','jl')
jl_manifest_df
# Out:
# /tmp/ipykernel_365916/1263118498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jl_manifest_df['province_code'] = jl_manifest_df['province_code'].replace('total','jl')
#                                                         ID  duration  \
# 147695   talk_set1_collectorjl9_speakerjl11_collectorjl...     6.804
# 147696   talk_set1_collectorjl9_speakerjl11_collectorjl...    10.180
# 147697   talk_set1_collectorjl9_speakerjl11_collectorjl...     3.243
# 147698   talk_set1_collectorjl9_speakerjl11_collectorjl...     2.819
# 147699   talk_set1_collectorjl9_speakerjl11_collectorjl...     1.510
# ...                                                    ...       ...
# 1307516          st_set1_collectorjl55_speakerjl205_85_7-0     5.061
# 1307517         st_set1_collectorjl55_speakerjl205_43_10-0     8.319
# 1307518         st_set1_collectorjl55_speakerjl206_70_12-0     7.639
# 1307519         st_set1_collectorjl55_speakerjl206_60_10-0     7.529
# 1307520          st_set1_collectorjl55_speakerjl205_98_8-0     5.779
#
#                                                        wav province_code  \
# 147695   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...            jl
# 147696   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...            jl
# 147697   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...            jl
# 147698   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...            jl
# 147699   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...            jl
# ...                                                    ...           ...
# 1307516  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            jl
# 1307517  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            jl
# 1307518  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            jl
# 1307519  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            jl
# 1307520  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            jl
#
#                                                  wrd
# 147695          어 농사지어본 적은 없구 무슨 작물을 재배해 본 적도 없고 그러네
# 147696                        아 부추로는 나물을 해 먹고 그래야지 아
# 147697                                        이 인 대화
# 147698                         어르신께서는 형제 관계가 어떻게 되세요
# 147699                                    다들 어디에 사세요
# ...                                              ...
# 1307516               여서부터는 어두워서 위험한게 내 손 깍 잡고 따라오쇼잉
# 1307517     아이 내가 친정에서는 밥 해 먹고 빨래하고 했지만 밭이는 어머니가 지었제
# 1307518     나는 아침에 닭장에 들어오면 닭하고 느그들이 알 낳냐 이러고 이야기도 혀
# 1307519  이녁이 먹을 것이라 약을 덜 해서 여기는 풀을 매고 매고 해도 너무 많이 돋소
# 1307520        가게 아가씨한테 말이라도 붙여볼라고 일부러 담배 사고 가고 그랬당게
#
# [376360 rows x 5 columns]

# %%
jl_manifest_file = "/data/MTDATA/fn-2-018/sentence/jl.csv"
jl_manifest_df = pd.read_csv(jl_manifest_file)

# split total csv into train, valid, test
jl_manifest_train_df, jl_manifest_valid_df, jl_manifest_test_df = np.split(
    jl_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(jl_manifest_df)), int(.9*len(jl_manifest_df))]
)

jl_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/jl_train.csv"
jl_manifest_train_df.to_csv(jl_manifest_train_file, index=False)

jl_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/jl_valid.csv"
jl_manifest_valid_df.to_csv(jl_manifest_valid_file, index=False)

jl_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/jl_test.csv"
jl_manifest_test_df.to_csv(jl_manifest_test_file, index=False)

# %%
jj_filter = total_manifest_df["ID"].str.contains("speakerjj")
jj_manifest_df = total_manifest_df[jj_filter]
jj_manifest_df['province_code'] = jj_manifest_df['province_code'].replace('total','jj')
jj_manifest_df
# Out:
# /tmp/ipykernel_365916/780198504.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jj_manifest_df['province_code'] = jj_manifest_df['province_code'].replace('total','jj')
#                                                         ID  duration  \
# 296438   talk_set1_collectorjj71_speakerjj461_speakerjj...     6.779
# 296439   talk_set1_collectorjj71_speakerjj461_speakerjj...    10.839
# 296440   talk_set1_collectorjj71_speakerjj461_speakerjj...     1.479
# 296441   talk_set1_collectorjj71_speakerjj461_speakerjj...     8.975
# 296442   talk_set1_collectorjj71_speakerjj461_speakerjj...     0.575
# ...                                                    ...       ...
# 1357030          st_set1_collectorjj10_speakerjj13_106_8-0     4.279
# 1357031          st_set1_collectorjj10_speakerjj13_107_8-0     3.400
# 1357032          st_set1_collectorjj10_speakerjj13_60_10-0     5.461
# 1357033           st_set1_collectorjj10_speakerjj13_84_7-0     2.717
# 1357034          st_set1_collectorjj10_speakerjj13_67_11-0     5.399
#
#                                                        wav province_code  \
# 296438   /data/MTDATA/fn-2-018/sentence/people/talk/jj/...            jj
# 296439   /data/MTDATA/fn-2-018/sentence/people/talk/jj/...            jj
# 296440   /data/MTDATA/fn-2-018/sentence/people/talk/jj/...            jj
# 296441   /data/MTDATA/fn-2-018/sentence/people/talk/jj/...            jj
# 296442   /data/MTDATA/fn-2-018/sentence/people/talk/jj/...            jj
# ...                                                    ...           ...
# 1357030  /data/MTDATA/fn-2-018/sentence/person/st/jj/co...            jj
# 1357031  /data/MTDATA/fn-2-018/sentence/person/st/jj/co...            jj
# 1357032  /data/MTDATA/fn-2-018/sentence/person/st/jj/co...            jj
# 1357033  /data/MTDATA/fn-2-018/sentence/person/st/jj/co...            jj
# 1357034  /data/MTDATA/fn-2-018/sentence/person/st/jj/co...            jj
#
#                                                        wrd
# 296438   언니는 아플 때 병원부터 감수강 집이서 생강 곹은 거 딸려 먹어기네 감수강 감기 걸릴 때
# 296439   금방게 기침 허고 목 아플 때사게 생강이영 배영 유지영 놔그네 딸령 먹어봥 혼 호루...
# 296440                                           나도 겅 헴수다게
# 296441   그 그 병원에 금방 가기는 낫을 것 곹으민 허주마는 그거 헤 겡 딸령 먹어그네 낫으...
# 296442                                                  맞아
# ...                                                    ...
# 1357030                            가게비가 자꾸 우는 걸 보난 비 옴 직허다
# 1357031                              이젠 가메기덜도 잘 안 보이는 거 닮아
# 1357032                            몸이 자꾸 구러운 거 보난 니가 신 셍이여
# 1357033                                   이 궤기 앗앙 강 갈랑 먹으라
# 1357034                               조나 보린 보셀왓디 농사가 잘 안 돼
#
# [74682 rows x 5 columns]

# %%
jj_manifest_file = "/data/MTDATA/fn-2-018/sentence/jj.csv"
jj_manifest_df = pd.read_csv(jj_manifest_file)

# split total csv into train, valid, test
jj_manifest_train_df, jj_manifest_valid_df, jj_manifest_test_df = np.split(
    jj_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(jj_manifest_df)), int(.9*len(jj_manifest_df))]
)

jj_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/jj_train.csv"
jj_manifest_train_df.to_csv(jj_manifest_train_file, index=False)

jj_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/jj_valid.csv"
jj_manifest_valid_df.to_csv(jj_manifest_valid_file, index=False)

jj_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/jj_test.csv"
jj_manifest_test_df.to_csv(jj_manifest_test_file, index=False)

# %%
cc_filter = total_manifest_df["ID"].str.contains("speakercc")
cc_manifest_df = total_manifest_df[cc_filter]
cc_manifest_df['province_code'] = cc_manifest_df['province_code'].replace('total','cc')
cc_manifest_df
# Out:
# /tmp/ipykernel_365916/3810001485.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_manifest_df['province_code'] = cc_manifest_df['province_code'].replace('total','cc')
#                                                         ID  duration  \
# 74568    talk_set3_collectorcc175_speakercc2218_speaker...     1.930
# 74569    talk_set3_collectorcc175_speakercc2218_speaker...     7.650
# 74570    talk_set3_collectorcc175_speakercc2218_speaker...     2.970
# 74571    talk_set3_collectorcc175_speakercc2218_speaker...     5.089
# 74572    talk_set3_collectorcc175_speakercc2218_speaker...     5.230
# ...                                                    ...       ...
# 1277430        st_set1_collectorjl171_speakercc1939_11_6-0     3.319
# 1277431        st_set1_collectorjl171_speakercc1963_25_7-0     6.639
# 1277432        st_set3_collectorjl171_speakercc1870_54_6-0     5.279
# 1277433       st_set2_collectorjl171_speakercc1837_11_10-0     9.419
# 1277434        st_set1_collectorjl171_speakercc1963_23_4-0     3.160
#
#                                                        wav province_code  \
# 74568    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...            cc
# 74569    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...            cc
# 74570    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...            cc
# 74571    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...            cc
# 74572    /data/MTDATA/fn-2-018/sentence/people/talk/cc/...            cc
# ...                                                    ...           ...
# 1277430  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            cc
# 1277431  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            cc
# 1277432  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            cc
# 1277433  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            cc
# 1277434  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...            cc
#
#                                                    wrd
# 74568                                육아는 부모가 해야 된다고 봐요
# 74569    손녀딸이 돌 지나기 전에 며느리가 허리 디스크가 있어서 왔더라고요 인천에서 사는데
# 74570                             그래서 내가 봐주게 됐어요 손녀 딸을
# 74571            오 월 오 일 어린이날 와서 십이 월까지 봐줬는데 쪼금 힘들더라고요
# 74572       나 취미 생활도 못하고 그런데 애기는 엄마 아빠가 키워야 된다고 봐요 저는요
# ...                                                ...
# 1277430                               자꾸 피는데 우티게 해야 돼유
# 1277431       무수짱아치를 맹글 때 동치미 무수를 메칠 담갔다가 바깥에 늘어 놔야 돼요
# 1277432            부모 말씀 거역하는 짓이 채고 큰 불효니까 부모님 말씀 잘 들어
# 1277433      갑자기 사리가 들렸다고 십분 넘게 따꾹질이 안 멈춘다는데 우디게 해야 돼요
# 1277434                          쇠죽을 쑤어야겠는데 저가 워디 있는 겨
#
# [351841 rows x 5 columns]

# %%
cc_manifest_file = "/data/MTDATA/fn-2-018/sentence/cc.csv"
cc_manifest_df = pd.read_csv(cc_manifest_file)

# split total csv into train, valid, test
cc_manifest_train_df, cc_manifest_valid_df, cc_manifest_test_df = np.split(
    cc_manifest_df.sample(frac=1, random_state=7774), 
    [int(.8*len(cc_manifest_df)), int(.9*len(cc_manifest_df))]
)

cc_manifest_train_file = "/data/MTDATA/fn-2-018/sentence/cc_train.csv"
cc_manifest_train_df.to_csv(cc_manifest_train_file, index=False)

cc_manifest_valid_file = "/data/MTDATA/fn-2-018/sentence/cc_valid.csv"
cc_manifest_valid_df.to_csv(cc_manifest_valid_file, index=False)

cc_manifest_test_file = "/data/MTDATA/fn-2-018/sentence/cc_test.csv"
cc_manifest_test_df.to_csv(cc_manifest_test_file, index=False)

# %%
# gw_manifest_file = "/data/MTDATA/fn-2-018/sentence/gw.csv"
# gs_manifest_file = "/data/MTDATA/fn-2-018/sentence/gs.csv"
# jl_manifest_file = "/data/MTDATA/fn-2-018/sentence/jl.csv"
# jj_manifest_file = "/data/MTDATA/fn-2-018/sentence/jj.csv"
cc_manifest_file = "/data/MTDATA/fn-2-018/sentence/cc.csv"

# gw_manifest_df.to_csv(gw_manifest_file, index=False)
# gs_manifest_df.to_csv(gs_manifest_file, index=False)
# jl_manifest_df.to_csv(jl_manifest_file, index=False)
# jj_manifest_df.to_csv(jj_manifest_file, index=False)
cc_manifest_df.to_csv(cc_manifest_file, index=False)

# %%
jl_manifest_df
# Out:
#                                                         ID  duration  \
# 147695   talk_set1_collectorjl9_speakerjl11_collectorjl...     6.804
# 147696   talk_set1_collectorjl9_speakerjl11_collectorjl...    10.180
# 147697   talk_set1_collectorjl9_speakerjl11_collectorjl...     3.243
# 147698   talk_set1_collectorjl9_speakerjl11_collectorjl...     2.819
# 147699   talk_set1_collectorjl9_speakerjl11_collectorjl...     1.510
# ...                                                    ...       ...
# 1307516          st_set1_collectorjl55_speakerjl205_85_7-0     5.061
# 1307517         st_set1_collectorjl55_speakerjl205_43_10-0     8.319
# 1307518         st_set1_collectorjl55_speakerjl206_70_12-0     7.639
# 1307519         st_set1_collectorjl55_speakerjl206_60_10-0     7.529
# 1307520          st_set1_collectorjl55_speakerjl205_98_8-0     5.779
#
#                                                        wav province_code  \
# 147695   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total
# 147696   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total
# 147697   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total
# 147698   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total
# 147699   /data/MTDATA/fn-2-018/sentence/people/talk/jl/...         total
# ...                                                    ...           ...
# 1307516  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...         total
# 1307517  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...         total
# 1307518  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...         total
# 1307519  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...         total
# 1307520  /data/MTDATA/fn-2-018/sentence/person/st/jl/co...         total
#
#                                                  wrd
# 147695          어 농사지어본 적은 없구 무슨 작물을 재배해 본 적도 없고 그러네
# 147696                        아 부추로는 나물을 해 먹고 그래야지 아
# 147697                                        이 인 대화
# 147698                         어르신께서는 형제 관계가 어떻게 되세요
# 147699                                    다들 어디에 사세요
# ...                                              ...
# 1307516               여서부터는 어두워서 위험한게 내 손 깍 잡고 따라오쇼잉
# 1307517     아이 내가 친정에서는 밥 해 먹고 빨래하고 했지만 밭이는 어머니가 지었제
# 1307518     나는 아침에 닭장에 들어오면 닭하고 느그들이 알 낳냐 이러고 이야기도 혀
# 1307519  이녁이 먹을 것이라 약을 덜 해서 여기는 풀을 매고 매고 해도 너무 많이 돋소
# 1307520        가게 아가씨한테 말이라도 붙여볼라고 일부러 담배 사고 가고 그랬당게
#
# [376360 rows x 5 columns]

# %%
print(f'토탈 시간 합계 : {total_manifest_df.duration.sum()/3600}')
print(f'강원 시간 합계 : {gw_manifest_df.duration.sum()/3600}')
print(f'경상 시간 합계 : {gs_manifest_df.duration.sum()/3600}')
print(f'전라 시간 합계 : {jl_manifest_df.duration.sum()/3600}')
print(f'제주 시간 합계 : {jj_manifest_df.duration.sum()/3600}')
print(f'충청 시간 합계 : {cc_manifest_df.duration.sum()/3600}')
# Out:
# 토탈 시간 합계 : 3045.770679166665
# 강원 시간 합계 : 543.8198133333335
# 경상 시간 합계 : 793.3567497222222
# 전라 시간 합계 : 869.2863738888888
# 제주 시간 합계 : 157.26691388888887
# 충청 시간 합계 : 682.0382972222221
