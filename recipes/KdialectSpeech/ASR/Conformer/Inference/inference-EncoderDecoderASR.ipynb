# %%
import os
import sys
from speechbrain.pretrained import EncoderDecoderASR
import IPython.display as ipd

# %%
provice_code = 'jl'

pretrained_model_src_dir = 'pretrained-model-src'
pretrained_model_save_dir = 'pretrained-model-save'

source = os.path.join(pretrained_model_src_dir, provice_code)
savedir = os.path.join(pretrained_model_save_dir, provice_code)

# %%
asr_model = EncoderDecoderASR.from_hparams(
    source=source,
    savedir=savedir,
    run_opts={"device":"cuda"}
)

# %%
### kspon
# audio_file = '/data/KsponSpeech/test/eval_clean/KsponSpeech_E02998.wav'
# audio_file = '/data/KsponSpeech/test/eval_clean/KsponSpeech_E00099.wav'

### gw
# audio_file = '/data/MTDATA/fn-2-018/root/person/say/gw/collectorgw57/say_set1_collectorgw57_speakergw463_87_1_24-0.wav'
# audio_file = '/data/MTDATA/fn-2-018/root/person/say/gw/collectorgw57/say_set1_collectorgw57_speakergw432_48_0_59-2.wav'
# audio_file = '/data/MTDATA/fn-2-018/root/person/say/gw/collectorgw42/say_set1_collectorgw42_speakergw212_19_0_37-2.wav'
# audio_file = "/data/MTDATA/fn-2-018/sentence/people/talk/gw/collectorgw137/talk_set2_collectorgw137_speakergw2930_speakergw2931_4_0_80-7.wav"
# audio_file = "/data/MTDATA/fn-2-018/sentence/people/talk/gw/collectorgw128/talk_set3_collectorgw128_speakergw1076_speakergw1077_9_0_148-0.wav"
# audio_file = "/data/MTDATA/fn-2-018/sentence/person/say/gw/collectorgw191/say_set1_collectorgw191_speakergw2117_63_0_55-1.wav"

### gs
# audio_file = "/data/MTDATA/fn-2-018/sentence/people/talk/gs/collectorgs384/talk_set1_collectorgs384_speakergs3119_speakergs3120_11_0_83-1.wav"

### jl
audio_file = "/data/MTDATA/fn-2-018/sentence/person/say/jl/collectorjl73/say_set1_collectorjl73_speakerjl960_5_0_38-0.wav"

### jj
# audio_file = "/data/MTDATA/fn-2-018/sentence/people/talk/jj/collectorjj78/talk_set2_collectorjj78_speakerjj581_speakerjj582_7_0_94-0"

### cc
# audio_file = "/data/MTDATA/fn-2-018/sentence/person/say/cc/collectorcc170/say_set2_collectorcc170_speakercc2173_47_0_52-0.wav"
# audio_file = "/data/MTDATA/fn-2-018/sentence/person/say/cc/collectorcc76/say_set2_collectorcc76_speakercc2472_0_0_28-0.wav"

# %%
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(asr_model.transcribe_file(audio_file))
# Out:
# 지금 입은 옷은 요것은 나는 인터넷으로 구매한 것인디 아니구만 이건 인터넷이 아니고 어디 저기 엔씨 엔씨 에이브라고 거기서 산 건 것 같은디
